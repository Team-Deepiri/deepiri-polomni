# %% [markdown]
# # Experiment 10 — Falsification Trinity (P1–P3)
#
# Tests simultaneous predictions from FALSIFICATION_CRITERIA.md.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({"figure.figsize": (9, 5), "font.size": 11})
print(f"polomni root: {ROOT}")

# %%
from polomni.math.proofs import falsification as f
for fn in [f.prove_p1, f.prove_p2, f.prove_p3]:
    r = fn()
    print(r.id, 'PASS' if r.passed else 'FAIL', r.message)
    assert r.passed
