# %% [markdown]
# # Experiment 18 — P1 Null Tier Comparison on Real WMAP
#
# Compare S_RBLE against N0/N1/N2 null tiers on cached WMAP Ka-band.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from polomni.observatory.studies.p1_runner import run_p1_study

result = run_p1_study(calibration=True)
print('S_RBLE', result['detection']['rble_score'])
print('null tiers', result['null_tier_comparison']['tiers'])
print('P1 supported', result['p1_supported'])
