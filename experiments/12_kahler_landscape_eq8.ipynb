# %% [markdown]
# # Experiment 12 — Kähler Landscape (Eq 8)
#
# Validates K_total and modulus stabilization rate.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({"figure.figsize": (9, 5), "font.size": 11})
print(f"polomni root: {ROOT}")

# %%
from polomni.core.landscape.kahler import kahler_total, modulus_stabilization_rate
from polomni.math.proofs.eq08_kahler import prove
r = prove()
print(r.message)
assert r.passed
t = 1.2 + 0.05j
ks = [kahler_total(t, i_trace=x*0.1, phi_stream_flux=0.05) for x in range(5)]
plt.plot(ks, 'o-'); plt.title('K_total vs I-trace'); plt.ylabel('K_total'); plt.savefig(ROOT/'data/figures/eq8_kahler.png', dpi=120); print('Saved figure')
