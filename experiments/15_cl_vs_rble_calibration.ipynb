# %% [markdown]
# # Experiment 15 — Planck C_l vs RBLE Calibration
#
# Compare Planck TT chi2_red against CAMB LCDM and WMAP RBLE score.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from polomni.math.proofs.real_data import prove_planck_power_chi2, prove_wmap_rble_score
from polomni.observatory.pipeline.cache import DataCache

cache = DataCache()
chi2 = prove_planck_power_chi2(cache)
wmap = prove_wmap_rble_score(cache, target_nside=128)
print(chi2.message)
print(wmap.message)
assert chi2.passed and wmap.passed
