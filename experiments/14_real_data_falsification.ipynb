# %% [markdown]
# # Experiment 14 — Real-Data Falsification (P1–P3)
#
# Run `polomni falsify --real` on cached WMAP/Planck/GW data with Bonferroni-corrected sky search.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from polomni.math.falsification_runner import run_falsification

report = run_falsification(real=True, fetch=False, save=False)
print(report.to_dict()["flags"])
assert report.all_passed
