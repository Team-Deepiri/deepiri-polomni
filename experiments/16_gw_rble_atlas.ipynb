# %% [markdown]
# # Experiment 16 — GW–RBLE Conductance Atlas
#
# Verify GWTC detector-network conductance symmetry (P3).

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from polomni.math.proofs.real_data import prove_gw_conductance
from polomni.observatory.pipeline.cache import DataCache

cache = DataCache()
gw = prove_gw_conductance(cache)
print(gw.message)
assert gw.passed
