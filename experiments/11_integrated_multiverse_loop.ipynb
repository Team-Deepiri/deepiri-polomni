# %% [markdown]
# # Experiment 11 — Integrated Multiverse Loop
#
# District graph → vacuum stream → RBLE workflow.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src" / "polomni").is_dir():
    ROOT = ROOT.parent
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({"figure.figsize": (9, 5), "font.size": 11})
print(f"polomni root: {ROOT}")

# %%
from polomni.integration.workflow import run_lab_workflow
from polomni.math import prove_all
w = run_lab_workflow(target_nside=32, null_ensemble=5, fetch_gw=False)
suite = prove_all(save=False)
print('GW count', w.gw_count)
print('RBLE score', w.pipeline_result.detection.rble_score)
print('Proofs', suite.passed_count, '/', len(suite.results))
assert w.pipeline_result.detection.rble_score > 0
assert suite.all_passed
